# %% [markdown]
# ####MTH00050 – Combinatorial Mathematics | 2025 - 2026 | D.KE - FIT - HCMUS
#
# ---
# ## <center>**PRACTICAL COURSEWORK REGULATIONS**</center>
#
# ### I. Schedule
# <center>
#
# | Week | Time | Content |
# |:---:|--- |---|
# | 1 |21/01|General counting method: Arrangements and Selections | # Theory exercises only: 1.1 (6+11) 1.2 (3+9) + intro python
# | 2 |28/01|General counting method: with Repetitions and Distributions | # Theory exercises only: 1.3(4+2) 1.4 (5+11) + python simulation (lab1)
# | 3 |04/02|Inclusion-Exclusion Formula | # Theory exercises: 4 (1+4+8)
# | Break | 11/02-25/02| Lunar New Year |
# | 4 | 04/03|Recurrence Relation |  # Theory exercises: 3 (1+2+4+5) + python recurrence relation
# | 5 | 11/03|Generating functions | # Theory exercise: 2 (2+4+11) + python generating functions + readfile (release file dữ liệu để ktra => hàm readfile)
# | Break | 18/03| Theory Midterm |
# | 6 | 25/03|Graph: Path and Circle | # Theory exercises: BTC1.BVThach (1+31+34) +  intro python class (class Graph => traversal nếu có thời gian)
# | 7 | 01/04|Shortest path | # Theory exercises: BTC3.BVThach (1+3+7) + python bfs shortest path
# | 8 | 08/04 |Trees and Tree algorithms | # Theory exercises: BTC2.BVThach (1+3+6) + python spanning tree/check connected
# | 9 | 15/04|Network and Flow problem | # BTC4.BVThach (1+4) + python Ford-Fullkerson
# | 10 | 22/04 |**Final**  | # full test (60'): include readfile + build class Graph + shortest path + spanning tree + ...
# | 11 |  |Retake (if any) | # for anyone who legally absent (mail before test) for midterm/final
#
# </center>
#
# *Note: This schedule is subject to change based on the theory class.*
#
# ### II. Regulations
# ##### **Grading**:
# - The exercise part comprises 20% of the course and will be assessed through a final exam test on the 10th week of class.
#
# ##### **Attendance**:
# - Missing a test or exam without an approved, pre-arranged excuse will result in a score of ZERO.
# - Any scheduled absence must be informed at least 1 hour before the test/exam begins. For any unscheduled absence, proper proof must be included.
#
# ### III. Plagiarism & Cheating
# - Plagiarism and cheating are strictly prohibited. A score of ZERO for the entire practical part will be issued to any student caught plagiarizing or cheating, and anyone involved. All such cases will be reported to the Management
# Board for further action.
# - Any portion of an exam solution or test solution with high similarity (above 70%) to another source will be considered cheating.
# - Copying any code snippet without proper citation in comments or referencing the source is considered plagiarism.
# - Any action intended to gain an unfair advantage, including (but not limited to) taking exams from unauthorized locations or collaborating without permission, will be considered cheating.
# - In cases where plagiarism or cheating is suspected but evidence remains inconclusive, students may be required to retake assessments (tests, exams, projects, etc.).
#
# ##### <center>--- THE END ---</center>
